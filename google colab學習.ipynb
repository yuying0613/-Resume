# %%
from google.colab import drive
drive.mount("/content/MyGoogleDrive")
# Out:
# Drive already mounted at /content/MyGoogleDrive; to attempt to forcibly remount, call drive.mount("/content/MyGoogleDrive", force_remount=True).

# %%
import pandas as pd
df = pd.read_csv("/content/MyGoogleDrive/MyDrive/python期末考/penguin.csv")
df
# Out:
#       ID  Length_cm  Weight_g            Species         Scientific Name  \
# 0      1       45.0    2847.0  Galapagos penguin   Spheniscus mendiculus
# 1      2       53.0    3625.0  Chinstrap penguin  Pygoscelis antarcticus
# 2      3       83.0    3600.0  Chinstrap penguin  Pygoscelis antarcticus
# 3      4       72.0    3282.0  Chinstrap penguin  Pygoscelis antarcticus
# 4      5        NaN    5630.0     Gentoo penguin        Pygoscelis papua
# ..   ...        ...       ...                ...                     ...
# 333  334       64.0    3752.0  Chinstrap penguin  Pygoscelis antarcticus
# 334  335       45.0    2300.0  Galapagos penguin   Spheniscus mendiculus
# 335  336       53.0     897.0     Little penguin         Eudyptula minor
# 336  337       37.0     812.0     Little penguin         Eudyptula minor
# 337  338       74.0    6013.0     Gentoo penguin        Pygoscelis papua
#
#        Inspector Measurement Date
# 0          Janet        1990/9/19
# ...

# %% [markdown]
# 2-3

# %%
df.isnull().sum()
# Out:
# ID                   0
# Length_cm           23
# Weight_g             9
# Species              0
# Scientific Name      0
# Inspector            0
# Measurement Date     0
# dtype: int64

# %% [markdown]
# 4

# %%
df = df.drop_duplicates()
df[df.duplicated()]
# Out:
# Empty DataFrame
# Columns: [ID, Length_cm, Weight_g, Species, Scientific Name, Inspector, Measurement Date]
# Index: []

# %%
df
# Out:
#       ID  Length_cm  Weight_g            Species         Scientific Name  \
# 0      1       45.0    2847.0  Galapagos penguin   Spheniscus mendiculus
# 1      2       53.0    3625.0  Chinstrap penguin  Pygoscelis antarcticus
# 2      3       83.0    3600.0  Chinstrap penguin  Pygoscelis antarcticus
# 3      4       72.0    3282.0  Chinstrap penguin  Pygoscelis antarcticus
# 4      5        NaN    5630.0     Gentoo penguin        Pygoscelis papua
# ..   ...        ...       ...                ...                     ...
# 333  334       64.0    3752.0  Chinstrap penguin  Pygoscelis antarcticus
# 334  335       45.0    2300.0  Galapagos penguin   Spheniscus mendiculus
# 335  336       53.0     897.0     Little penguin         Eudyptula minor
# 336  337       37.0     812.0     Little penguin         Eudyptula minor
# 337  338       74.0    6013.0     Gentoo penguin        Pygoscelis papua
#
#        Inspector Measurement Date
# 0          Janet        1990/9/19
# ...

# %% [markdown]
# 5

# %%
df[df["Length_cm"].isnull() ==True]
# Out:
#       ID  Length_cm  Weight_g            Species         Scientific Name  \
# 4      5        NaN    5630.0     Gentoo penguin        Pygoscelis papua
# 55    56        NaN    5577.0  Chinstrap penguin  Pygoscelis antarcticus
# 61    62        NaN    5830.0     Gentoo penguin        Pygoscelis papua
# 69    68        NaN    5543.0     Gentoo penguin        Pygoscelis papua
# 77    75        NaN     842.0  Galapagos penguin   Spheniscus mendiculus
# 80    78        NaN    5846.0  Chinstrap penguin  Pygoscelis antarcticus
# 133  132        NaN     813.0  Galapagos penguin   Spheniscus mendiculus
# 138  137        NaN    7528.0     Gentoo penguin        Pygoscelis papua
# 173  172        NaN    1007.0  Galapagos penguin   Spheniscus mendiculus
# 175  174        NaN    4919.0  Chinstrap penguin  Pygoscelis antarcticus
# 177  176        NaN    7048.0     Gentoo penguin        Pygoscelis papua
# 184  183        NaN    6633.0     Gentoo penguin        Pygoscelis papua
# ...

# %%
df
# Out:
#       ID  Length_cm  Weight_g            Species         Scientific Name  \
# 0      1       45.0    2847.0  Galapagos penguin   Spheniscus mendiculus
# 1      2       53.0    3625.0  Chinstrap penguin  Pygoscelis antarcticus
# 2      3       83.0    3600.0  Chinstrap penguin  Pygoscelis antarcticus
# 3      4       72.0    3282.0  Chinstrap penguin  Pygoscelis antarcticus
# 4      5        NaN    5630.0     Gentoo penguin        Pygoscelis papua
# ..   ...        ...       ...                ...                     ...
# 333  334       64.0    3752.0  Chinstrap penguin  Pygoscelis antarcticus
# 334  335       45.0    2300.0  Galapagos penguin   Spheniscus mendiculus
# 335  336       53.0     897.0     Little penguin         Eudyptula minor
# 336  337       37.0     812.0     Little penguin         Eudyptula minor
# 337  338       74.0    6013.0     Gentoo penguin        Pygoscelis papua
#
#        Inspector Measurement Date
# 0          Janet        1990/9/19
# ...

# %%
df[df["Weight_g"].isnull() ==True]
# Out:
#       ID  Length_cm  Weight_g            Species         Scientific Name  \
# 52    53       77.0       NaN  Chinstrap penguin  Pygoscelis antarcticus
# 98    96       51.0       NaN  Chinstrap penguin  Pygoscelis antarcticus
# 126  124       52.0       NaN  Galapagos penguin   Spheniscus mendiculus
# 128  127       39.0       NaN     Little penguin         Eudyptula minor
# 134  133       48.0       NaN  Chinstrap penguin  Pygoscelis antarcticus
# 186  185       63.0       NaN  Galapagos penguin   Spheniscus mendiculus
# 226  226       97.0       NaN     Gentoo penguin        Pygoscelis papua
# 276  277      111.0       NaN     Gentoo penguin        Pygoscelis papua
# 307  308       56.0       NaN  Galapagos penguin   Spheniscus mendiculus
#
#        Inspector Measurement Date
# 52         Janet        1990/9/22
# 98       Raymond         1990/9/1
# 126        Janet        1991/6/11
# 128       Elbert        1990/9/20
# 134        Janet         1991/3/2
# ...

# %%
print(df.isnull().sum())
# Out:
# ID                   0
# Length_cm           23
# Weight_g             9
# Species              0
# Scientific Name      0
# Inspector            0
# Measurement Date     0
# dtype: int64

# %%
df = pd.read_csv("/content/MyGoogleDrive/MyDrive/python期末考/penguin.csv")
print(df.dropna(how='any').shape)
# Out:
# (306, 7)

# %%
print(df.dropna(how='all').shape)
df.info()
# Out:
# (338, 7)
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 338 entries, 0 to 337
# Data columns (total 7 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   ID                338 non-null    int64
#  1   Length_cm         315 non-null    float64
#  2   Weight_g          329 non-null    float64
#  3   Species           338 non-null    object
#  4   Scientific Name   338 non-null    object
#  5   Inspector         338 non-null    object
#  6   Measurement Date  338 non-null    object
# dtypes: float64(2), int64(1), object(4)
# memory usage: 18.6+ KB

# %%
df.duplicated()
# Out:
# 0      False
# 1      False
# 2      False
# 3      False
# 4      False
#        ...
# 333    False
# 334    False
# 335    False
# 336    False
# 337    False
# Length: 338, dtype: bool

# %%
df = df.drop_duplicates()

# %%
df[df.duplicated()]
# Out:
# Empty DataFrame
# Columns: [ID, Length_cm, Weight_g, Species, Scientific Name, Inspector, Measurement Date]
# Index: []

# %%
o_filepath = "/content/MyGoogleDrive/MyDrive/python期末考/penguin.csv"
GooglePath = o_filepath

# %%
print(df.isnull().sum())
# Out:
# ID                   0
# Length_cm           23
# Weight_g             9
# Species              0
# Scientific Name      0
# Inspector            0
# Measurement Date     0
# dtype: int64

# %%
df.info
# Out:
# <bound method DataFrame.info of       ID  Length_cm  Weight_g            Species         Scientific Name  \
# 0      1       45.0    2847.0  Galapagos penguin   Spheniscus mendiculus
# 1      2       53.0    3625.0  Chinstrap penguin  Pygoscelis antarcticus
# 2      3       83.0    3600.0  Chinstrap penguin  Pygoscelis antarcticus
# 3      4       72.0    3282.0  Chinstrap penguin  Pygoscelis antarcticus
# 4      5        NaN    5630.0     Gentoo penguin        Pygoscelis papua
# ..   ...        ...       ...                ...                     ...
# 333  334       64.0    3752.0  Chinstrap penguin  Pygoscelis antarcticus
# 334  335       45.0    2300.0  Galapagos penguin   Spheniscus mendiculus
# 335  336       53.0     897.0     Little penguin         Eudyptula minor
# 336  337       37.0     812.0     Little penguin         Eudyptula minor
# 337  338       74.0    6013.0     Gentoo penguin        Pygoscelis papua
#
#        Inspector Measurement Date
# ...

# %%
df = df.dropna()

# %%
print(df.isnull().sum())
# Out:
# ID                  0
# Length_cm           0
# Weight_g            0
# Species             0
# Scientific Name     0
# Inspector           0
# Measurement Date    0
# dtype: int64

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 300 entries, 0 to 337
# Data columns (total 7 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   ID                300 non-null    int64
#  1   Length_cm         300 non-null    float64
#  2   Weight_g          300 non-null    float64
#  3   Species           300 non-null    object
#  4   Scientific Name   300 non-null    object
#  5   Inspector         300 non-null    object
#  6   Measurement Date  300 non-null    object
# dtypes: float64(2), int64(1), object(4)
# memory usage: 18.8+ KB

# %%
df.reset_index(drop=True)
# Out:
#       ID  Length_cm  Weight_g            Species         Scientific Name  \
# 0      1       45.0    2847.0  Galapagos penguin   Spheniscus mendiculus
# 1      2       53.0    3625.0  Chinstrap penguin  Pygoscelis antarcticus
# 2      3       83.0    3600.0  Chinstrap penguin  Pygoscelis antarcticus
# 3      4       72.0    3282.0  Chinstrap penguin  Pygoscelis antarcticus
# 4      6       83.0    5678.0     Gentoo penguin        Pygoscelis papua
# ..   ...        ...       ...                ...                     ...
# 295  334       64.0    3752.0  Chinstrap penguin  Pygoscelis antarcticus
# 296  335       45.0    2300.0  Galapagos penguin   Spheniscus mendiculus
# 297  336       53.0     897.0     Little penguin         Eudyptula minor
# 298  337       37.0     812.0     Little penguin         Eudyptula minor
# 299  338       74.0    6013.0     Gentoo penguin        Pygoscelis papua
#
#        Inspector Measurement Date
# 0          Janet        1990/9/19
# ...

# %%
df.head()
# Out:
#    ID  Length_cm  Weight_g            Species         Scientific Name  \
# 0   1       45.0    2847.0  Galapagos penguin   Spheniscus mendiculus
# 1   2       53.0    3625.0  Chinstrap penguin  Pygoscelis antarcticus
# 2   3       83.0    3600.0  Chinstrap penguin  Pygoscelis antarcticus
# 3   4       72.0    3282.0  Chinstrap penguin  Pygoscelis antarcticus
# 5   6       83.0    5678.0     Gentoo penguin        Pygoscelis papua
#
#      Inspector Measurement Date
# 0        Janet        1990/9/19
# 1       Elbert        1991/6/21
# 2        Janet        1991/3/17
# 3  Antisthenes        1991/3/25
# 5      Raymond       1990/12/20

# %%
s = {"Chinstrap penguin":0, "Little penguin":1, "Galapagos penguin":2}
df["Species"]=df["Species"].map(s)
df.head()
# Out:
# <ipython-input-263-84ba9e9993c1>:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df["Species"]=df["Species"].map(s)
#    ID  Length_cm  Weight_g  Species         Scientific Name    Inspector  \
# 0   1       45.0    2847.0      NaN   Spheniscus mendiculus        Janet
# 1   2       53.0    3625.0      NaN  Pygoscelis antarcticus       Elbert
# 2   3       83.0    3600.0      NaN  Pygoscelis antarcticus        Janet
# 3   4       72.0    3282.0      NaN  Pygoscelis antarcticus  Antisthenes
# 5   6       83.0    5678.0      NaN        Pygoscelis papua      Raymond
#
#   Measurement Date
# 0        1990/9/19
# 1        1991/6/21
# 2        1991/3/17
# 3        1991/3/25
# 5       1990/12/20

# %%
o_filepath = "/content/MyGoogleDrive/MyDrive/python期末考/1104A051.csv"
GooglePath = o_filepath
fiename="1104A051.csv"
df.to_csv(GooglePath + "1104A051.csv")

# %%
filename="1104A051.csv"
df.to_csv(GooglePath+"1104A051.csv")
